# %%
import pyautogui
import time
import pandas
import sys

# %%
pyautogui.PAUSE = 0.5
pyautogui.click(x=938, y=602)
pyautogui.press("ESC", presses= 2)
pyautogui.click(x=52, y=140)
time.sleep(1)
pyautogui.click(x=278, y=72)
time.sleep(1)

# %%
#Lendo banco de dados
dtype_dict= {'QTDE': str, 'fitac1': str,'fitac2': str,'fital1': str,'fital2': str,'caixa': str,'comp_ou_usin': str,}
tabela = pandas.read_excel("Criação cópia.xlsx", sheet_name="Filtragem", dtype=dtype_dict)
df=tabela
print(tabela)
pyautogui.write(str(tabela['caixa'].iloc[0]))
pyautogui.press("enter")
 #Indo para a alteração da caixa
pyautogui.press("a")
    
    #Adicionando itens da caixa
for linha in tabela.index:
    volume = tabela.loc[linha, "VOLUME"]   
    time.sleep(1)    
        
    if volume == "A":
        pyautogui.click(x=2169, y=780)
        pyautogui.doubleClick(x=345, y=72)
        pyautogui.press("backspace", presses = 20)
        time.sleep(1)
        caixa = tabela.loc[linha, "caixa"]
        pyautogui.write(caixa)
        pyautogui.press("enter")
        pyautogui.press("a")
        pyautogui.press("U")
        pyautogui.press("tab")
        novo = tabela.loc[linha, "novo"]
        pyautogui.write(novo)
        pyautogui.press("enter")
        pyautogui.write(tabela.loc[linha, "QTDE"])
        pyautogui.press("enter", presses = 2)
        pyautogui.press("tab")
    
    elif volume == 'B':
        pyautogui.click(x=2169, y=780)
        pyautogui.doubleClick(x=345, y=72)
        pyautogui.press("backspace", presses = 20)
        time.sleep(1)
        caixa = tabela.loc[linha, "caixa"]
        pyautogui.write(caixa)
        pyautogui.press("enter")
        pyautogui.press("a")
        pyautogui.press("U")
        pyautogui.press("tab")
        novo = tabela.loc[linha, "novo"]
        pyautogui.write(novo)
        pyautogui.press("enter")
        pyautogui.write(tabela.loc[linha, "QTDE"])
        pyautogui.press("enter", presses = 2)
        pyautogui.press("tab")

    elif volume == 'C':
        pyautogui.click(x=2169, y=780)
        pyautogui.doubleClick(x=345, y=72)
        pyautogui.press("backspace", presses = 20)
        time.sleep(1)
        caixa = tabela.loc[linha, "caixa"]
        pyautogui.write(caixa)
        pyautogui.press("enter")
        pyautogui.press("a")
        pyautogui.press("U")
        pyautogui.press("tab")
        novo = tabela.loc[linha, "novo"]
        pyautogui.write(novo)
        pyautogui.press("enter")
        pyautogui.write(tabela.loc[linha, "QTDE"])
        pyautogui.press("enter", presses = 2)
        pyautogui.press("tab")


    elif volume == 'D':
        pyautogui.click(x=2169, y=780)
        pyautogui.doubleClick(x=345, y=72)
        pyautogui.press("backspace", presses = 20)
        time.sleep(1)
        caixa = tabela.loc[linha, "caixa"]
        pyautogui.write(caixa)
        pyautogui.press("enter")
        pyautogui.press("a")
        pyautogui.press("U")
        pyautogui.press("tab")
        novo = tabela.loc[linha, "novo"]
        pyautogui.write(novo)
        pyautogui.press("enter")
        pyautogui.write(tabela.loc[linha, "QTDE"])
        pyautogui.press("enter", presses = 2)
        pyautogui.press("tab")
# Out:
#         CODIGO     DESCRICAO QTDE    COMP   LARG   ESP VOLUME       novo  \
# 0   IW-3657.16         TAMPO    1  1820.0  370.0  15.0      A  FJ8177.38
# 1   IW-3657.16         TAMPO    1  1820.0  370.0  15.0      B  FJ8177.38
# 2   IW-3657.16         TAMPO    1  1820.0  370.0  15.0      A  FJ8177.38
# 3   IW-3657.16         TAMPO    1  1820.0  370.0  15.0      A  FJ8177.38
# 4      DP-3915  FUNDO BRANCO    3   561.0  306.0   3.0      B  FJ4370.38
# 5      DP-3915  FUNDO BRANCO    3   561.0  306.0   3.0      B  FJ4370.38
# 6      DP-3915  FUNDO BRANCO    3   561.0  306.0   3.0      C  FJ4370.38
# 7   TL-3919.16         FUNDO    1  1198.0  617.0   3.0      C  FJ0785.38
# 8   TL-3919.16         FUNDO    1  1198.0  617.0   3.0      D  FJ0785.38
# 9   TL-3919.16         FUNDO    1  1198.0  617.0   3.0      C  FJ0785.38
# 10  TL-3938.16         FUNDO    1   617.0  506.0   3.0      D  FJ0786.38
# 11  TL-3938.16         FUNDO    1   617.0  506.0   3.0      C  FJ0786.38
# ...
