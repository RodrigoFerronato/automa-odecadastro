# %%
import pyautogui
import time
import pandas
import pyperclip
import sys

# %%
pyautogui.click(x=192, y=1007)

#Lendo banco de dados
dtype_dict= {'QTDE': str, 'fitac1': str,'fitac2': str,'fital1': str,'fital2': str,'caixa': str,'comp_ou_usin': str,}
tabela = pandas.read_excel("Criação cópia.xlsx", sheet_name="Filtragem", dtype=dtype_dict)
print(tabela)

#Digitando a caixa
for linha in tabela.index:
    time.sleep(2)
    caixa = tabela.loc[linha, "caixa"]
    pyautogui.write(caixa)
    pyautogui.press("tab", presses = 3)
    pyautogui.press("enter", presses=2)
    pyautogui.press("esc")
    pyautogui.press("esc")  
    pyautogui.press("tab", presses= 5)


pyautogui.press("esc")
pyautogui.PAUSE = 0.4

pyautogui.click(x=1306, y=458)
pyautogui.press("esc")
pyautogui.click(x=59, y=967)
pyautogui.click(x=56, y=314)
# Out:
#        CODIGO                  DESCRICAO QTDE    COMP   LARG   ESP VOLUME  \
# 0  IW-4370.16        PRATELEIRA SEM FURO    1   782.0  345.0  12.0      A
# 1  IW-0785.16   LATERAL DIREITA SUPERIOR    1  1020.0  250.0  12.0      A
# 2  IW-0786.16  LATERAL ESQUERDA SUPERIOR    1  1100.0  250.0  12.0      A
# 3  AP-8177.44         TRASEIRO DE GAVETA    1   551.0   95.0  12.0      A
# 4         NaN                        NaN  NaN     NaN    NaN   NaN    NaN
# 5         NaN                        NaN  NaN     NaN    NaN   NaN    NaN
# 6         NaN                        NaN  NaN     NaN    NaN   NaN    NaN
# 7         NaN                             NaN     NaN    NaN   NaN    NaN
#
#         novo     antigo    chapa  ...  fitac1  descrição fitac1  fital1  \
# 0  FJ4370.38  IW4370.16  12688.0  ...  014610  FITA FREIJÓ 15MM  014610
# 1  FJ0785.38  IW0785.16  12688.0  ...  014610  FITA FREIJÓ 15MM  014610
# 2  FJ0786.38  IW0786.16  12688.0  ...  014610  FITA FREIJÓ 15MM  014610
# ...

# %%
#Lendo banco de dados
dtype_dict= {'QTDE': str, 'fitac1': str,'fitac2': str,'fital1': str,'fital2': str,'caixa': str,'comp_ou_usin': str,}
tabela = pandas.read_excel("Criação cópia.xlsx", sheet_name="Filtragem", dtype=dtype_dict)
print(tabela)

#Digitando a caixa
for linha in tabela.index:
    time.sleep(2)
    caixa = tabela.loc[linha, "caixa"]
    pyautogui.write(caixa)
    pyautogui.press("enter", presses = 3)
    pyautogui.press("D")
    pyautogui.press("enter", presses=3)
    pyautogui.press("C")
    pyautogui.write(caixa)
    pyautogui.press("enter", presses= 4)
    pyautogui.press("esc")
    pyautogui.press("tab", presses = 2)
# Out:
#         CODIGO                     DESCRICAO QTDE    COMP   LARG   ESP VOLUME  \
# 0   IW-4370.16           PRATELEIRA SEM FURO    1   782.0  345.0  12.0      A
# 1   IW-0785.16      LATERAL DIREITA SUPERIOR    1  1020.0  250.0  12.0      A
# 2   IW-0786.16     LATERAL ESQUERDA SUPERIOR    1  1100.0  250.0  12.0      A
# 3   AP-8177.44            TRASEIRO DE GAVETA    1   551.0   95.0  12.0      A
# 4   IW-0784.16  LATERAL ESQUERDA DO GABINETE    1   655.0  350.0  12.0      A
# 5   IW-2313.16                SARRAFO CHAPEU    1  1196.0   80.0  12.0      A
# 6   IW-4368.16  PRATELEIRA PARAFUSO SUPERIOR    1   600.0  250.0  12.0      A
# 7   IW-4369.16           PRATELEIRA SEM FURO    1   600.0  250.0  12.0      A
# 8   IW-3652.16            BASE ARMARIO AEREO    1  1184.0  250.0  12.0      A
# 9   IW-3653.16                    BASE NICHO    1  1184.0  250.0  12.0      A
# 10  IW-3656.16                          BASE    1  1820.0  350.0  15.0      A
# ...
